# %%
import pandas as pd

# %%
anger = pd.read_csv("AngerData.csv", delimiter='\t')
fear = pd.read_csv("FearData.csv", delimiter='\t')
joy = pd.read_csv("JoyData.csv", delimiter='\t')
love = pd.read_csv("LoveData.csv", delimiter='\t')
neutral = pd.read_csv("NeutralData.csv", delimiter='\t')

# %%
anger["mood"] = "Marah"
fear["mood"] = "Takut"
joy["mood"] = "Senang"
love["mood"] = "Kasih"
neutral["mood"] = "Netral"
sad["mood"] = "Sedih"

# %% [markdown]
# #Gabungkan menjadi satu data

# %%
# Gabungkan semua DataFrame
combined_df = pd.concat([anger, fear, joy, love, neutral, sad])

# Cek hasil gabungan
combined_df.head()
# Out:
#                                                Tweet  Label   mood
# 0                        pagi2 udah di buat emosi :)  Anger  Marah
# 1  kok stabilitas negara, memange 10 thn negara t...  Anger  Marah
# 2                       dah lah emosi mulu liat emyu  Anger  Marah
# 3  aib? bodoh benar! sebelum kata aib itu muncul,...  Anger  Marah
# 4                            dih lu yg nyebelin bego  Anger  Marah

# %% [markdown]
# #Bersihkan data

# %%
#Cleaning Text
def clean_text(text):
    text = str(text).lower()                          # ubah ke huruf kecil
    text = re.sub(r'http\S+|www\S+', '', text)        # hapus link
    text = re.sub(r'@\w+', '', text)                  # hapus mention
    text = re.sub(r'#\w+', '', text)                  # hapus hashtag
    text = emoji.replace_emoji(text, replace='')      # hapus emoji
    text = re.sub(r'[^a-zA-Z\s]', '', text)           # hapus angka, emoji, simbol
    text = re.sub(r'\s+', ' ', text).strip()          # hapus spasi berlebih
    return text

# %%
combined_df.to_csv("mood_dataset.csv", index=False)
